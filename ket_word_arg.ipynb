# %%
def fun(**argu):
    for k, val in argu.items():
        print(k,val)
fun(a=12)

# %%
def run(*k):
    return sum(k)
print(run(12,33))
# Out:
# 45

# %%
def info(*a,**b):
    print("11",a)
    print("22",b)

info(10,22,33,a=5,b=2)
# Out:
# 11 (10, 22, 33)
# 22 {'a': 5, 'b': 2}
