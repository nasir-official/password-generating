# %%
##   for show error in profficinal way
try:
    num =int(input("Entre number"))
    print("number is",num)
except ValueError:
    print("Invalid syntaxt try again ..")
# Out:
# Invalid syntaxt try again ..

# %%
try:
    div= int(input("Enter first number .."))
    div1= int(input("Enter second number.."))
    total=div / div1
    print("total= ",total)
except ZeroDivisionError:
    print("Cnanot divide by zero....")
except ValueError:
    print("Value error")
# Out:
# Value error
