# %%
def my_decurator(func):
    def wrapp():
        print("before")
        func()
        print("after")
    return wrapp
@my_decurator
def show():
    print("mid jdsnfs")
show()
# Out:
# before
# mid jdsnfs
# after
