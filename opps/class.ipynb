# %%
class Car:
    color="pink"
    model="texla"
    price="$1000"
    def display(self):
        print(f"COLOR IS {self.color} model is {self.model} price is {self.price}")
car1=Car()
car1.display()

# %%
#constractor
class info:
    name="nasir"
    age=17
    def i(self):
        print(f" my name is {self.name}  i am {self.age} years old")
    def __init__(self):
        print("this is constructor")
        name="nasir"
        self.i()

info1=info()

# %%
class std:
    def __init__(self):
        self.name="ali"

a=std()
print(a.name)
# Out:
# ali
