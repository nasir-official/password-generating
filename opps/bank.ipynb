# %%
class Bank:
    def __init__(self,balance=10):
        self.__balance = balance
        while True:
            print("======Bank System======")
            print("1. Deposit")
            print("2. Withdraw")
            print("3. check Balance")
            print("4. Exit")
            option = int(input("Choose an option: "))
            if option == 1:
                self.__deposit()
            elif option == 2:
                self.__withdraw()
            elif option == 3:
                print(f"Current balance: {self.__check_balance()}")
            elif option == 4:
                print("Exiting the system. Goodbye!")
                break
            else:
                print("Invalid option. Please try again.")
    
    def __deposit(self):
        amount=int(input("Enter amount to deposit: "))
        if amount > 0:
            self.__balance += amount
            print(f"Deposited amount: {amount}. New balance: {self.__balance}")
        else:
            print("Deposit amount must be positive.")
    def __withdraw(self):
        amount = int(input("Enter amount to withdraw: "))
        if self.__balance >= amount:
            self.__balance -= amount
            print(f"Withdrew amount: {amount}. New balance: {self.__balance}")
        else:
            print("invalid withdrawal amount.")
    def __check_balance(self):
        return self.__balance
info = Bank()
##info.deposit(500)
# Out:
# ======Bank System======
# 1. Deposit
# 2. Withdraw
# 3. check Balance
# 4. Exit
# invalid withdrawal amount.
# ======Bank System======
# 1. Deposit
# 2. Withdraw
# 3. check Balance
# 4. Exit
# Deposited amount: 200. New balance: 210
# ======Bank System======
# 1. Deposit
# 2. Withdraw
# 3. check Balance
# 4. Exit
# Withdrew amount: 100. New balance: 110
# ======Bank System======
# 1. Deposit
# 2. Withdraw
# 3. check Balance
# 4. Exit
# Current balance: 110
# ======Bank System======
# 1. Deposit
# 2. Withdraw
# 3. check Balance
# 4. Exit
# Exiting the system. Goodbye!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4508\1591969675.py in <module>
#      39 info = Bank()
#      40 ##info.deposit(500)
# ---> 41 info.__check_balance()
#
# AttributeError: 'Bank' object has no attribute '__check_balance'
