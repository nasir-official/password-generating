# %%
#DATA INCAPSULATION
class bank:
    def __init__(self,balance):
    
        self.__balance = balance  #private 
    def deposit(self,amount):
        self.__balance+=amount
        print("deposite amount",self.__balance)
    def withdral(self,amount):
        if amount > self.__balance:
              print("inciftion balance ")
        elif amount <= self.__balance:
            self.__balance-=amount
            print("withdral amount",self.__balance)

b= bank(12000)
b.deposit(100)
b.withdral(10000)
# Out:
# deposite amount 12100
# inciftion balance
