# %%
print("hellow world")
# Out:
# hellow world

# %%
#Electric Bill
billunit = 5
name=input("Enter your Name")
mounth=input("Enter a Bill Mounth")
amount=float(input("Enter your total Units consume"))
total=amount*billunit
late=input("Your late yes/no ??")
if late=="yes":
    if amount>=0 and amount<=100:
        print("you are late fee is Rs:500")
        total=total+500
        print(f"Total Amount is {total}")
    if amount>100 and amount<=200:
        print("you are late fee is Rs:1000")
        total=total+1000
        print(f"Total amount is {total}")
    if amount>200 and amount<=300:
        print("you are late fee is Rs:2000")
        total=total+2000
        print(f"Total amount is {total}")
    if amount>300 and amount<=400:
        print("you are late fee is Rs:3000")
        total=total+3000
        print(f"Total amount is {total}")
    if amount>400 and amount<=500:
        print("you are late fee is Rs:5000")
        total=total+5000
        print(f"Total amount is {total}")
    if amount<501:
        print(f"your bill is too high warning")
elif late=="no":
    totalamount=amount*billunit
    print(f"Your Total amount is Rs:{totalamount}")
else:
    print("sntaxt error")
print(f"Name: {name}")
print(f"Mounth : {mounth}")
print(f"Total Units {amount}")
print(f" Good Luck for pay! ")
# Out:
# Your Total amount is Rs:610.0
# Name: Muhammad Nasir
# Mounth : May
# Total Units 122.0
#  Good Luck for pay!

# %%
a=int(input("enter your name"))
if a<0:
    print("Negative Number")
else:
    print("Positive NUmber")
# Out:
# Negative Number

# %%
num1=int(input("Enter Number"))
num2=int(input("Enter second Number"))
print("num1 is grater than num2" if num1>num2 else "Num2 is grater than num1 ")
# Out:
# Num2 is grater than num1

# %%
#ATM System
print("________THE ATM SYSTEM________")
balance=50
pin=1234
name="muhammad nasir"
user=int(input("Enter Your PIN number"))
uname=int(input("Entere Your User Name"))
if user==pin & name==uname:
    print("  ATM MENU  ")
    print("WithDral / press 1")
    print("Deposite / press 2")
    print("check balance / press 3")
    option=int(input("choice option"))
    if option==1:
        withdral=int(input("Enter  Withdral Amount"))
        if withdral>balance:
            print("Balance is incfitiant")
        elif withdral<balance:
            balance=balance-withdral
            print(f"Your Current Amount {balance}")
    elif option==2:
        deposite=int(input("Enter Your Deposite Amount"))
        balance+=deposite
        print(f"Your Total Amount is {balance}") 
    elif option==3:
        print(f"Your Total Balance is Rs: {balance}")
    else:
        print("Sory Your type wrong")
else:
     print("Your PIN no. is Wrong")
# Out:
# ________THE ATM SYSTEM________
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8604\3517046097.py in <module>
#       5 name="muhammad nasir"
#       6 user=int(input("Enter Your PIN number"))
# ----> 7 uname=int(input("Entere Your User Name"))
#       8 if user==pin & name==uname:
#       9     print("  ATM MENU  ")
#
# ValueError: invalid literal for int() with base 10: 'muhammad nasir'
