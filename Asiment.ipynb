# %%
#STUDENT INFO
print("Well come")
def info(roll_no):
    if roll_no==1:
            print(" name = Muhammad Nasir")
            print(" f_name = Hassan")
            print(" Class = AI Engeneering")
            print(" dob = 12-june-2009")
            print(" section = Tulip")
            print(" roll_no = 1")
    elif roll_no==2:
        
           print(" name = Muhammad Aslam")
           print(" f_name = Ali")
           print(" class = Web Development")
           print(" dob = 01-Dec-2008")
           print(" section = Tulip")
           print(" roll_no = 2")
    elif roll_no==3:
        
           print(" name = kamran Ali")
           print(" f_name = Haider")
           print("class = Data Science")
           print(" dob = 05-may-2010")
           print(" section = Tulip")
           print(" roll_no = 3")
    elif roll_no==4:
        
           print(" name = Aslam Ali")
           print(" f_name = Muhammad")
           print(" class = Full Stract Development")
           print(" dob = 25-Aug-2007")
           print(" section = Tulip")
           print(" roll_no = 4")
    elif roll_no==5:
        
            print(" name = Aqeel Ahmed")
            print(" f_name = Anwar Ali")
            print(" class = Python Programming")
            print(" dob = 09-jan-2009")
            print(" section = Tulip")
            print(" roll_no = 5")

def result():
       
roll_no=int(input("Enter Roll no. :  "))
info(roll_no)
# Out:
# Well come
#  name = Muhammad Aslam
#  f_name = Ali
#  class = Web Development
#  dob = 01-Dec-2008
#  section = Tulip
#  roll_no = 2
