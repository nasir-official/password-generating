# %%
#------------------------------                      ---------------#
#------------------------------Digital library System---------------#

#____________class book_________
class book:
    def __init__(self,book_id,title,author):
        self.book_id = book_id
        self.title = title
        self.author = author
       ## self.is_issued = False 

#___________class Library_______
class library:
    def __init__(self):
        self.books = []
    def add_book(self,book):
        if id in self.books:
            print("sorry book is already avaliable")
        else:
            self.books.append(book)
            print("Book is published now!")
    def desplay_books(self):
        
        print(f" Book ID = {self.book_id}")
        print(f" Title = {self.title}")
        print(f" Auther = {self.author}")


library_obj = library()
print("_________WELL COME TO DIGITAL LIBRARY SYSTEM______")
print("Add Book  / press 1")
print("Display books  / press 2")
print("Exit  / press 3")
option = int(input("Your choice..."))
while True:
    if option == 1:
        book_id = int(input("Enter your book ID"))
        title = input("Enter your book title ")
        author = input("Enter Auther name")
        book_info =book(book_id,title,author)
        library_obj.add_book(book_info)
        add = int(input("Any more want to add /  yes=1  no=2"))
        if add==1:
            continue
        elif add ==2:
            break
        else:
            print("Typing mistake")
    elif option == 2:
        library_obj.desplay_books()
    elif option == 3:
        print("program exit ")
        break
    else:
        print("Wrong typing")
        continue
# Out:
# _________WELL COME TO DIGITAL LIBRARY SYSTEM______
# Add Book  / press 1
# Display books  / press 2
# Exit  / press 3
#  no book is avaliable
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2708\678978792.py in <module>
#      49             print("Typing mistake")
#      50     elif option == 2:
# ---> 51         library_obj.desplay_books()
#      52     elif option == 3:
#      53         print("program exit ")
#
# ~\AppData\Local\Temp\ipykernel_2708\678978792.py in desplay_books(self)
#      23         if not self.books:
#      24             print(" no book is avaliable")
# ---> 25         print(f" Book ID = {self.book_id}")
#      26         print(f" Title = {self.title}")
#      27         print(f" Auther = {self.author}")
#
# AttributeError: 'library' object has no attribute 'book_id'
