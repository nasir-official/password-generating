# %%
##User define function
def student(id_no):  ##Arguments
    if id_no==1:    ##condition
        print("___Student info___")
        info=[1," Muhammad Ali","Hassan","AI",17,"02-jan-2009"] ##list data
        print(f"ID: {info[0]}")    ##print by indexing
        print(f"Name: {info[1]}")
        print(f"Father Name {info[2]}")
        print(f"Class : {info[3]}")
        print(f"Age: {info[4]}")
        print(f"DOB : {info[5]}")
    elif id_no==2:   ##condition
        print("Student info")
        info=[2," Muhammad Aslam","haider","data science",18,"12-june-2007"]
        print(f"ID: {info[0]}")
        print(f"Name: {info[1]}")
        print(f"Father Name {info[2]}")
        print(f"Class : {info[3]}")
        print(f"Age: {info[4]}")
        print(f"DOB : {info[5]}")
    elif id_no==3:
        print("Student info")
        info=[3," Akram Ali","Habib ","data science",17,"02-july-2008"]
        print(f"ID: {info[0]}")
        print(f"Name: {info[1]}")
        print(f"Father Name {info[2]}")
        print(f"Class : {info[3]}")
        print(f"Age: {info[4]}")
        print(f"DOB : {info[5]}")
    elif id_no==4:
        print("Student info")
        info=[4,"Yaseen ali","muhammad ali","data Analytics",19,"17-Aug-2006"]
        print(f"ID: {info[0]}")
        print(f"Name: {info[1]}")
        print(f"Father Name {info[2]}")
        print(f"Class : {info[3]}")
        print(f"Age: {info[4]}")
        print(f"DOB : {info[5]}")
    elif id_no==5:
        print("Student info")
        info=[5,"Saqlane ali","Sabir ali","python (Advance)",19,"22-sep-2006"]
        print(f"ID: {info[0]}")
        print(f"Name: {info[1]}")
        print(f"Father Name {info[2]}")
        print(f"Class : {info[3]}")
        print(f"Age: {info[4]}")
        print(f"DOB : {info[5]}")
    ## user define function
def result(id_no):  #arguments
    print("___Student Progress___")
    if id_no==1:
        all_sub = (46,47,42,45,49,43,39)  ##Tuple data
        print(f"English : {all_sub[0]}") ##by indexing
        print(f"Mathematics : {all_sub[1]}")
        print(f"Urdu : {all_sub[2]}")
        print(f"Physics : {all_sub[3]}")
        print(f" Chemistry : {all_sub[4]}")
        print(f"Computer : {all_sub[5]}")
        print(f"Islamiyat : {all_sub[6]}")
        total=all_sub[0]+all_sub[1]+all_sub[2]+all_sub[3]+all_sub[4]+all_sub[5]+all_sub[6]  #find sum of all number
        percent=total/350*100   ## percent formula
        print(f"Total marks : ",350,"Obtain Marks : ",total)
        print(f"Percentage :  ",percent,"%")
        grade(percent) ##calling function with perameter
       ## class_report(percent)
    if id_no==2:
        all_sub = (49,42,42,47,39,48,39)
        print(f"English : {all_sub[0]}")
        print(f"Mathematics : {all_sub[1]}")
        print(f"Urdu : {all_sub[2]}")
        print(f"Physics : {all_sub[3]}")
        print(f" Chemistry : {all_sub[4]}")
        print(f"Computer : {all_sub[5]}")
        print(f"Islamiyat : {all_sub[6]}")
        total=all_sub[0]+all_sub[1]+all_sub[2]+all_sub[3]+all_sub[4]+all_sub[5]+all_sub[6]
        percent=total/350*100
        print(f"Total marks : ",350,"Obtain Marks : ",total)
        print(f"Percentage :  ",percent,"%")
        grade(percent)
      ##  class_report(percent)
    if id_no==3:
        all_sub = (40,42,41,37,49,44,44)
        print(f"English : {all_sub[0]}")
        print(f"Mathematics : {all_sub[1]}")
        print(f"Urdu : {all_sub[2]}")
        print(f"Physics : {all_sub[3]}")
        print(f" Chemistry : {all_sub[4]}")
        print(f"Computer : {all_sub[5]}")
        print(f"Islamiyat : {all_sub[6]}")
        total=all_sub[0]+all_sub[1]+all_sub[2]+all_sub[3]+all_sub[4]+all_sub[5]+all_sub[6]
        percent=total/350*100
        print(f"Total marks : ",350,"Obtain Marks : ",total)
        print(f"Percentage :  ",percent,"%")
        grade(percent)
       ## class_report(percent)
    if id_no==4:
        all_sub = (48,32,45,47,40,42,34)
        print(f"English : {all_sub[0]}")
        print(f"Mathematics : {all_sub[1]}")
        print(f"Urdu : {all_sub[2]}")
        print(f"Physics : {all_sub[3]}")
        print(f" Chemistry : {all_sub[4]}")
        print(f"Computer : {all_sub[5]}")
        print(f"Islamiyat : {all_sub[6]}")
        total=all_sub[0]+all_sub[1]+all_sub[2]+all_sub[3]+all_sub[4]+all_sub[5]+all_sub[6]
        percent=total/350*100
        print(f"Total marks : ",350,"Obtain Marks : ",total)
        print(f"Percentage :  ",percent,"%")
        grade(percent)
       ## class_report(percent)
    if id_no==5:
        all_sub = (30,46,43,47,39,34,49)
        print(f"English : {all_sub[0]}")
        print(f"Mathematics : {all_sub[1]}")
        print(f"Urdu : {all_sub[2]}")
        print(f"Physics : {all_sub[3]}")
        print(f" Chemistry : {all_sub[4]}")
        print(f"Computer : {all_sub[5]}")
        print(f"Islamiyat : {all_sub[6]}")
        total=all_sub[0]+all_sub[1]+all_sub[2]+all_sub[3]+all_sub[4]+all_sub[5]+all_sub[6]
       ## total= [id_no for id_no in range(len(all_sub))]
        percent=total/350*100

        print(f"Total marks : ",350,"Obtain Marks : ",total)
        print(f"Percentage :  ",percent,"%")
        grade(percent)
       ## class_report(percent)

       ##user define function
def grade(percent):
     if percent<40: ##condition
            print("Sorry Try Again")
     elif percent<=100 and percent>90:  ##and operator
            print("Grade : A++")
     elif percent<=90 and percent>80:
            print("Grade : A+")
     elif percent<=80 and percent>70:
            print("Grade : A")
     elif percent<=70 and percent>60:
            print("Grade : B") 
     elif percent<=50 and percent>40:
            print("Grade : C")

##def class_report_in(percent,id_no):
   ## print(" ")
   ## if id_no

print("Well come")
print("What Do you want to Do?")  ##input from user
print(" Student information / press 1")
print("Student Result / press 2")
print("Exit  /  press 4")
option = int(input("choice")) ##type casting
while True:   ##while loop to run again and again
    if option==1:
        list_id = [s for s in range(1,6)] ##list comprention
        id_no= int(input("Enter valid ID number"))  ##type casting
        if id_no==list_id[0] or id_no==list_id[1] or id_no==list_id[2] or id_no==list_id[3] or id_no==list_id[4]:  ##condition  ues or operator
           student(id_no)
        else:
             print("Enter valid ID number")
             continue  ##to run again
        user= int(input("Any more do you want to search /press  yes=1 , no=2"))  ##type casting
        if user==1: ##condition
            continue
        elif user==2:
            break  ##To exicute
        else:
            print("typing mistake")
       
    elif option==2: 
        list_id = [s for s in range(1,6)]  ##list comperantion
        id_no= int(input("Enter valid ID number"))
        if id_no==list_id[0] or id_no==list_id[1] or id_no==list_id[2] or id_no==list_id[3] or id_no==list_id[4]:
           result(id_no)
        else:
             print("Enter valid ID number")
             continue
        user= int(input("Any more do you want to search /press  yes=1 , no=2"))
        if user==1:
            continue
        elif user==2:
            break
        else:
            print("typing mistake")
    elif option== 3:
        print("Program Exit")
        break  ##exicute
    else:  ##for other
        print("wrong syntaxt")
# Out:
# Well come
# What Do you want to Do?
#  Student information / press 1
# Student Result / press 2
# Exit  /  press 4
# Enter valid ID number
# ___Student Progress___
# English : 30
# Mathematics : 46
# Urdu : 43
# Physics : 47
#  Chemistry : 39
# Computer : 34
# Islamiyat : 49
# Total marks :  350 Obtain Marks :  288
# Percentage :   82.28571428571428 %
# Grade : A+
